# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Rietaros/kampus_merdeka/main/HRDataset_v14.csv')
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
# ...

# %% [markdown]
# # Pandas Question

# %% [markdown]
# 1. What is the minimum, median, max, and average salary for employee by Married Description and Gender.
# Hints: use agg function<br>
# Expected Output as below<br>
# (5 Points)

# %%
# 1. What is the minimum, median, max, and average salary for employee by Married Description and Gender
# Hints: use agg function
# Expected Output as below
# (5 Points)

# %%
no_1 = data.groupby(['MaritalDesc', 'Sex'])['Salary'].agg(['min', 'median', 'max', 'mean']) #menggabungkan column marital dan sex, lalu column salary diberi fungsi .agg untuk menghitung min,median,max,dan mean

# %%
no_1 = no_1.reset_index() #reset index ke bentuk default

# %%
no_1.columns = ['MaritalDesc', 'Sex', 'Min Salary', 'Median Salary', 'Max Salary', 'Average Salary'] #me-rename column sesuai index
print(no_1) #menampilkan hasilnya
# Out:
#   MaritalDesc Sex  Min Salary  Median Salary  Max Salary  Average Salary
# 0    Divorced   F       45069        59393.0       68182    57345.500000
# 1    Divorced  M        45115        63738.5      148999    72520.857143
# 2     Married   F       45433        62662.0      250000    69638.986111
# 3     Married  M        46120        63370.5      157000    70089.038462
# 4   Separated   F       52984        60627.0       66149    60658.888889
# 5   Separated  M        64397        70468.0       74417    69760.666667
# 6      Single   F       45395        62068.0      220450    68988.266667
# 7      Single  M        46428        63055.5      178000    71340.048387
# 8     Widowed   F       45046        63303.5      107226    69719.750000
# 9     Widowed  M        52788        61359.0       67176    60670.500000

# %% [markdown]
# 2. What is top-5 reason of termination?<br>
# Expected Output as below<br>
# (5 Points)

# %%
#no2

# %%
#term = data['TermReason']
#term = term.sort_values(ascending=False)

# %%
#print(term)

# %% [markdown]
# 3. What is the highest number of employee by Recruitment Source that 'Exceeds' the Performance Score?
# Hints: Use filter for Performance Score first. Don't forget to sort_values.<br>
# Expected Output as below<br>
# (5 Points)

# %%
#no3

# %%
filtered_data = data[data['PerformanceScore'] == 'Exceeds'] #mem-filter dataframe untuk baris yang performance scorenya melebihi batas
no_3 = filtered_data.groupby('RecruitmentSource')['PerformanceScore'].count() #mengelompokan data yg difilter berdasarkan recruitmentscore dan menghitung jumlah karyawan setiap sourcenya

# %%
no_3 = no_3.sort_values(ascending=False) #mengurutkan dari jumlah karyawan terbanyak ke terdikit, sehingga ascending dibuat false

# %%
highest_source = no_3.index[0] #untuk mendapatkan recruitmentsource dengan jumlah karyawan terbanyak yang melebihi batas index pertama [0]
highest_count = no_3.iloc[0] #untuk mendapatkan jumlah karyawan terbanyak yang melebihi batas index pertama [0]

# %%
print(no_3) #menampilkan hasil
print(f"The highest number of employees who 'Exceeds' the Performance Score is {highest_count} from the source '{highest_source}'.") #menampilkan highest_count dan highest_source. print(f"..") digunakan karena ada replacement field dengan sintaks'{}'
# Out:
# RecruitmentSource
# Indeed                12
# LinkedIn               9
# Diversity Job Fair     6
# Employee Referral      5
# CareerBuilder          2
# Google Search          2
# Website                1
# Name: PerformanceScore, dtype: int64
# The highest number of employees who 'Exceeds' the Performance Score is 12 from the source 'Indeed'.

# %% [markdown]
# 4. How many managers in each department?
# Hints: use nunique() as aggregation function.<br>
# Expected Output as below.<br>
# (5 Points)

# %%
#no4

# %%
no_4 = data.groupby('Department')['Position'].nunique() #nunique function berfungsi untuk menghitung jumlah unique positions (managers) tiap department
print(no_4)
# Out:
# Department
# Admin Offices            4
# Executive Office         1
# IT/IS                   18
# Production               4
# Sales                    3
# Software Engineering     2
# Name: Position, dtype: int64

# %%
#saya gangerti kenapa jumlahnya bisa beda :(

# %% [markdown]
# 5. What is Termination Ratio by Gender?.
# Hints: use value_counts(normalize=True).<br>
# Expected Output as below.<br>
# (5 Points)

# %%
#no5

# %%
termination = data.groupby('Sex')['Termd'].value_counts(normalize=True) #menghitung jumlah termination berdasarkan gender

# %%
no_5 = termination.iloc[:4] #slicing untuk index ke 0-3
print(no_5) #menampilkan hasil termination
# Out:
# Sex  Termd
# F    0        0.659091
#      1        0.340909
# M    0        0.674074
#      1        0.325926
# Name: Termd, dtype: float64

# %% [markdown]
# # Create an EDA and Data Visualization Question

# %%
#Sample Visualization, the example is not counted for the final score :p
#Create 5 visualization for better understanding on data
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

#Ratio termination by Gender

#Step1, get the data

term = data.groupby(by=['Sex'])\
                        .agg(total_termination=('Termd','sum')).reset_index()\

#Step2, Plot it
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='Sex', y='total_termination', hue='Sex', data=term, palette='cool')

# %% [markdown]
# 6. Buatlah Scatter plot antara kolom "Salary" dengan "EngagementSurvey", beri warna berbeda sesuai dengan status di "Termd"<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
#no6

# %%
no6_termd_1 = data[data['Termd'] == 1] #status 1 (terminated/diberhentikan)
no6_termd_0 = data[data['Termd'] == 0] #status 0 (active/masih bekerja)

plt.figure(figsize=(15, 8))  # mengatur ukuran plot

plt.scatter(no6_termd_1['Salary'], no6_termd_1['EngagementSurvey'], c='red', label='Termd=1') #scatter plot untuk status 1

plt.scatter(no6_termd_0['Salary'], no6_termd_0['EngagementSurvey'], c='blue', label='Termd=0') #scatter plot untuk status 0
plt.legend() #menambahkan bagian legend untuk status Termd berdasarkan warna

plt.xlabel('Salary') #untuk nama label di sumbu x
plt.ylabel('EngagementSurvey') #untuk nama label di sumby y
plt.title('Scatter Plot Salary vs EngagementSurvey berdasarkan Termd') #judul scatter plot

plt.show() #menampilkan plot

# %% [markdown]
# 7. Buatlah visualisasi barchart untuk menghitung jumlah "termination of an employee's" berdasarkan department.<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
#no7

# %%
no7_terminationofemployee = data.groupby('Department')['Termd'].sum() #menggabungkan data department dan total Termd di tiap department

plt.figure(figsize=(15, 8))  #mengatur ukuran plot

no7_terminationofemployee.plot(kind='bar', color=['red','orange','yellow','green','blue','purple']) #menentukan bentuk plot dan warna yang diinginkan

plt.xlabel('Department') #untuk nama label di sumbu x
plt.ylabel('Number of Terminations') #untuk nama label di sumbu y
plt.title('Number of Terminations by Department') #judul bar chart

plt.xticks(rotation=360) #mengatur rotasi label sumbu x

plt.show() #menampilkan plot

# %% [markdown]
# 8. Buatlah visualisasi Pie Chart untuk melihat persentasi jumlah karyawan yang "terminated" berdasarkan kolom "Position".<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
#no8

# %%
no8_terminationofemployee = data.groupby('Position')['Termd'].sum() #menggabungkan data Position dan total Termd di tiap department

plt.figure(figsize=(15, 8))  #mengatur ukuran plot

plt.pie(no8_terminationofemployee, labels=no8_terminationofemployee.index, autopct='%1.1f%%') #menentukan bentuk plot, nama label, dan numeric value (1 angka di belakang koma) pada piechart

plt.show() #menampilkan plot

# %% [markdown]
# 9. Buat Boxplot yang menggambarkan Salary berdasarkan Marital Desc, bedakan berdasarkan Termd
# (5 points)

# %%
fig = plt.figure(figsize=(15, 8))  # mengatur ukuran plot

bp = data.boxplot(column='Salary', by=['MaritalDesc','Termd'], figsize=(15,8))

plt.xlabel('MaritalDesc and Termd Status') #untuk nama label di sumbu x
plt.ylabel('Salary') #untuk nama label di sumby y
plt.title('Scatter Plot Salary berdasarkan MaritalDesc dan Termd') #judul scatter plot

plt.show() #menampilkan plot

# %% [markdown]
# 10. Tampilkan pairplot antara kolom 'Salary', 'EngagementSurvey', 'EmpSatisfaction','Absences'
# beri kategori warna berdasarkan 'Termd'<br>
# (5points)

# %%
#no10

# %%
print('Pairplot') #fungsi pairplot untuk menampilkan hubungan antara variabel dan dataset
sns.pairplot(data=data[['Salary', 'EngagementSurvey', 'EmpSatisfaction','Absences', 'Termd']], hue='Termd', height=4.8, diag_kind="hist") #kolom yang ingin diliat hubungannya yaitu Salary, EngagementSurvey, EmpSatisfaction, dan Absences berdasarkan status Termd
plt.show() #menampilkan plot
# Out:
# Pairplot

# %% [markdown]
# # Create Machine Learning Model to Predict Termd and Question

# %%
#11. Buat fitur baru (kolom baru) berupa "Age" dalam satuan tahun. Untuk mendapatkannya, ambil data pada kolom DOB dikurangi dengan 2022
#(5 points)

# %%
#12. Lakukan MinMaxScaler dari fitur "Salary"
# (5 points)
from sklearn.preprocessing import MinMaxScaler

# %%
#no12

# %%
scaler = MinMaxScaler() #menginisialisasi MinMaxScaler sebagai scaler
data['Salary_MinMax'] = scaler.fit_transform(data[['Salary']]) #.fit_transform untuk mempelajari parameternya dan menyimpan hasil transform ke data baru ('Salary_MinMax')

print(data[['Salary','Salary_MinMax']]) #menampilkan data 'Salary' dan 'Salary_MinMax', data yang ditunjukkan pada data baru akan diskalakan 0-1
# Out:
#      Salary  Salary_MinMax
# 0     62506       0.085190
# 1    104437       0.289777
# 2     64955       0.097139
# 3     64991       0.097315
# 4     50825       0.028197
# ..      ...            ...
# 306   65893       0.101716
# 307   48513       0.016916
# 308  220450       0.855821
# 309   89292       0.215883
# 310   45046       0.000000
#
# [311 rows x 2 columns]

# %%
#13. Ubahlah semua tipe data object menjadi category
# 5 point

# %%
#no13

# %%
data.select_dtypes(include=['object']).astype('category')
data.dtypes
#tipe data tetep object, apa karena tidak ada tipe data category????
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
#14. Ubahlah "RecruitmentSource" dengan menggunakana Label Encoder
# 5 point

#15. Ubahlah "PerformanceScore" dengan menggunakana Label Encoder
# 5 point
from sklearn.preprocessing import LabelEncoder

# %%
#no14

# %%
label_encoder = LabelEncoder() #menginisialisasi LabelEncoder sebagai label_encoder

data['Recruitment_Source_Encoded'] = label_encoder.fit_transform(data['RecruitmentSource']) #meng-encode kolom 'RecruitmentSource'

print(data[['RecruitmentSource', 'Recruitment_Source_Encoded']]) #menampilkan hasil data yang sudah ter-encode
# Out:
#      RecruitmentSource  Recruitment_Source_Encoded
# 0             LinkedIn                           5
# 1               Indeed                           4
# 2             LinkedIn                           5
# 3               Indeed                           4
# 4        Google Search                           3
# ..                 ...                         ...
# 306           LinkedIn                           5
# 307      Google Search                           3
# 308  Employee Referral                           2
# 309  Employee Referral                           2
# 310           LinkedIn                           5
#
# [311 rows x 2 columns]

# %%
#no15

# %%
label_encoder = LabelEncoder() #menginisialisasi LabelEncoder sebagai label_encoder

data['Performance_Score_Encoded'] = label_encoder.fit_transform(data['PerformanceScore']) #meng-encode kolom 'PerformanceScore'

print(data[['PerformanceScore', 'Performance_Score_Encoded']]) #menampilkan hasil data yang sudah ter-encode
# Out:
#     PerformanceScore  Performance_Score_Encoded
# 0            Exceeds                          0
# 1        Fully Meets                          1
# 2        Fully Meets                          1
# 3        Fully Meets                          1
# 4        Fully Meets                          1
# ..               ...                        ...
# 306      Fully Meets                          1
# 307              PIP                          3
# 308          Exceeds                          0
# 309      Fully Meets                          1
# 310      Fully Meets                          1
#
# [311 rows x 2 columns]

# %%
#16. Pisahkan dependent variable dan independent variable
# 5 point

#Dependent Varible (target)


#Independent Variable (feature)

# %%
#no16

# %%
#karena target kita untuk melihat siapa saja karyawan yang berhenti dan masih bekerja, jadi menurut saya dependent varialenya adalah kolom 'Termd'
y = data['Termd']  #mengidentifikasi y sebagai dependent variable (target) dan X sebagai independent variable (feature)
X = data.drop('Termd', axis=1)  #meng-drop dependent variable untuk mendapatkan independent variable saja

# %%
#17. Bagi data menjadi Train-Test sebesar 80:20
# (5 points)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_curve, roc_curve, precision_score, recall_score

# %%
#no17

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101) #membuat test set nya sebesar 20% agar training setnya 80%
#random_state bisa menggunakan nilai integer berapapun, atau None juga.

# %%
#18. Lakukan pemodelan machine learning (metode klasifikasi bebas) untuk bisa memprediksi status "Termd". Lakukan evaluasi hasil dengan menampilkan
# score klasifikasi, precision dan recall.
# Gunakan model yang menurut kalian terbaik
# (5 points)

# %%
#no18

# %%
from sklearn.metrics import f1_score
for name, model in models:
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)
    f_score=f1_score(y_test,predictions)
    msg="%s: %f" % (name, f_score)
    print(msg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-2e59adb0d519> in <cell line: 2>()
#       1 from sklearn.metrics import f1_score
#       2 for name, model in models:
# ----> 3     model.fit(X_train,y_train)
#       4     predictions = model.predict(X_test)
#       5     f_score=f1_score(y_test,predictions)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...

# %% [markdown]
# # Insight (Answering the Question)
#
# 19.	Is there any relationship between who a person works for (their manager) and their performance score? (5 points)<br>
# 20.	What are our best recruiting sources if we want to ensure a low ratio of termination? (5 points)<br>

# %%
#19 = harusnya ada.
#20 = mungkin dari indeed, karena sebelumnya kita udah dapat nilai performancescore tertinggi yaitu indeed dengan nilai 12, diikuti dengan linkedin dengan nilai 9
